# %% [markdown]
# # Import libraries

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
sns.set()
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
stock_cleaned_data=pd.read_csv('/Users/linhtrankhanh/Documents/GitHub/Prediction_stock/data/stock_cleaned_data.csv', index_col = 0)

# %%
stock_cleaned_data.head()
# Out:
#                 open      high       low     close   volume
# date
# 1999-11-01  136.5000  137.0000  135.5625  135.5625  4006500
# 1999-11-02  135.9687  137.2500  134.5937  134.5937  6516900
# 1999-11-03  136.0000  136.3750  135.1250  135.5000  7222300
# 1999-11-04  136.7500  137.3593  135.7656  136.5312  7907500
# 1999-11-05  138.6250  139.1093  136.7812  137.8750  7431500

# %% [markdown]
# # Visualisation

# %% [markdown]
# ## 1. Closing Price
# The closing price is the last price at which the stock is traded during the regular trading day. A stock’s closing price is the standard benchmark used by investors to track its performance over time.

# %%
plt.figure(figsize=(16, 8))
plt.title('Close Price History')
plt.plot(stock_cleaned_data.index, stock_cleaned_data['close'], linewidth=3, label='Close Price')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(loc='best')  # Display a legend if you have multiple lines on the chart
plt.grid(True)  # Add grid lines for reference
plt.show()

# %%
sns.histplot(x='volume', data=stock_cleaned_data)
# Out:
# <AxesSubplot:xlabel='volume', ylabel='Count'>

# %%
corr_coeff = stock_cleaned_data['volume'].corr(stock_cleaned_data['close'])
print('Correlation Coefficient:', corr_coeff)
sns.jointplot(x='close', y='volume', data=stock_cleaned_data, kind='reg', 
              line_kws={'color': 'purple'})

plt.xlabel('Adj Close Price')
plt.ylabel('Volume')
# Out:
# Correlation Coefficient: -0.17167271501483525
# Text(489.87301587301596, 0.5, 'Volume')

# %%
corr_coeff = stock_cleaned_data['volume'].corr(stock_cleaned_data['high'] - stock_cleaned_data['close'])
print('Correlation Coefficient:', corr_coeff)

sns.jointplot(x=stock_cleaned_data['high'] - stock_cleaned_data['close'], y='volume', data=stock_cleaned_data, kind='reg', 
              line_kws={'color': 'purple'})

plt.xlabel('high-low')
plt.ylabel('Volume')
# Out:
# Correlation Coefficient: 0.2044064936566659
# Text(489.87301587301596, 0.5, 'Volume')
